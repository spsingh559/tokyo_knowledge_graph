# %% [markdown]
# # Tokyo Olympics knowledge Graph

# %%
# Import libraries
import pandas as pd


# !pip install openpyxl

import warnings
warnings.filterwarnings("ignore")
# Out:
# Requirement already satisfied: openpyxl in /Users/bot/opt/anaconda3/lib/python3.8/site-packages (3.0.5)
# Requirement already satisfied: et-xmlfile in /Users/bot/opt/anaconda3/lib/python3.8/site-packages (from openpyxl) (1.0.1)
# Requirement already satisfied: jdcal in /Users/bot/opt/anaconda3/lib/python3.8/site-packages (from openpyxl) (1.4.1)

# %%
# import module
from geopy.geocoders import Nominatim

# %%
# initialize Nominatim API 
geolocator = Nominatim(user_agent="geoapiExercises")

# %% [markdown]
# ## Import Data

# %% [markdown]
# ### Players list

# %%
athletes = pd.read_excel('Athletes.xlsx', engine='openpyxl')
athletes.head()
# Out:
#                 Name     NOC           Discipline
# 0    AALERUD Katrine  Norway         Cycling Road
# 1        ABAD Nestor   Spain  Artistic Gymnastics
# 2  ABAGNALE Giovanni   Italy               Rowing
# 3     ABALDE Alberto   Spain           Basketball
# 4      ABALDE Tamara   Spain           Basketball

# %%
athletes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11085 entries, 0 to 11084
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Name        11085 non-null  object
#  1   NOC         11085 non-null  object
#  2   Discipline  11085 non-null  object
# dtypes: object(3)
# memory usage: 259.9+ KB

# %%
#create another columns to modify country names
athletes['country']=athletes['NOC']

# %%
# Replace ROC with Russia in country columns
athletes['country']=athletes['country'].replace(['ROC'],'Russia')

# %%
#Replace Refugee Olympic teams and assigh host olympic city name
athletes['country']=athletes['country'].replace(['Refugee Olympic Team'],'Tokyo')

# %%
# Get coordinates of each country
def get_country_coord (country):
    output = geolocator.geocode(country)
   
    if output is None:
        return [None,None]
    return [country,output[1][0],output[1][1]]

# %%
#get unique country list
country_list=athletes['country'].unique()

# %%
#map function on country list to get geo coordinates
geo_code=list(map(get_country_coord,country_list))

# %%
#create country data frame based on country name, lattitude and longitude
country_df=pd.DataFrame(geo_code,columns=['country','lat','lon'])

# %%
#mere the country data frame to athlete data frame 
athletes=pd.merge(athletes, country_df, on="country")

# %%
#getting the country name along with geo coordinates for geo visualisation
athletes
# Out:
#                        Name       NOC     Discipline   country        lat  \
# 0           AALERUD Katrine    Norway   Cycling Road    Norway  60.500021
# 1       ABELVIK ROED Magnus    Norway       Handball    Norway  60.500021
# 2        BERGERUD Torbjoern    Norway       Handball    Norway  60.500021
# 3        BJOERNSEN Kristian    Norway       Handball    Norway  60.500021
# 4      BLUMMENFELT Kristian    Norway      Triathlon    Norway  60.500021
# ...                     ...       ...            ...       ...        ...
# 11080          NAUNG Ye Tun   Myanmar       Shooting   Myanmar  17.175050
# 11081      THET HTAR Thuzar   Myanmar      Badminton   Myanmar  17.175050
# 11082            OPTI Soren  Suriname      Badminton  Suriname   4.141303
# 11083       TJON EN FA Jair  Suriname  Cycling Track  Suriname   4.141303
# 11084      TJON-A-JOE Renzo  Suriname       Swimming  Suriname   4.141303
#
#              lon
# 0       9.099972
# 1       9.099972
# 2       9.099972
# 3       9.099972
# 4       9.099972
# ...          ...
# 11080  95.999965
# 11081  95.999965
# 11082 -56.077119
# 11083 -56.077119
# 11084 -56.077119
#
# [11085 rows x 6 columns]

# %%
athletes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 11085 entries, 0 to 11084
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Name        11085 non-null  object
#  1   NOC         11085 non-null  object
#  2   Discipline  11085 non-null  object
#  3   country     11085 non-null  object
#  4   lat         11085 non-null  float64
#  5   lon         11085 non-null  float64
# dtypes: float64(2), object(4)
# memory usage: 606.2+ KB

# %%
# download athletes 
# athletes.to_csv('.\athelets_csv.csv')
athletes.to_csv (r'olympic_athelets.csv', index = False, header=True)

# %% [markdown]
# ### coaches list

# %%
coaches = pd.read_excel('Coaches.xlsx', engine='openpyxl')
coaches.head(21)
# Out:
#                            Name                       NOC         Discipline  \
# 0               ABDELMAGID Wael                     Egypt           Football
# 1                     ABE Junya                     Japan         Volleyball
# 2                 ABE Katsuhiko                     Japan         Basketball
# 3                  ADAMA Cherif             Côte d'Ivoire           Football
# 4                    AGEBA Yuya                     Japan         Volleyball
# 5     AIKMAN Siegfried Gottlieb                     Japan             Hockey
# 6                 AL SAADI Kais                   Germany             Hockey
# 7                 ALAMEDA Lonni                    Canada  Baseball/Softball
# 8               ALEKNO Vladimir  Islamic Republic of Iran         Volleyball
# 9               ALEKSEEV Alexey                       ROC           Handball
# 10  ALLER CARBALLO Manuel Angel                     Spain         Basketball
# 11                ALSHEHRI Saad              Saudi Arabia           Football
# 12                    ALY Kamal                     Egypt           Football
# 13          AMAYA GAITAN Fabian               Puerto Rico         Basketball
# 14             AMO AGUADO Pablo                     Spain           Football
# 15            ANDONOVSKI Vlatko  United States of America           Football
# 16                 ANNAN Alyson               Netherlands             Hockey
# 17           ARNAU CREUS Xavier                     Japan             Hockey
# 18                ARNOLD Graham                 Australia           Football
# 19                  AXNER Tomas                    Sweden           Handball
# 20           BABER Gareth Colin                      Fiji       Rugby Sevens
#
#        Event
# 0        NaN
# 1        NaN
# 2        NaN
# 3        NaN
# 4        NaN
# 5        Men
# 6        Men
# 7   Softball
# 8        Men
# 9      Women
# 10       NaN
# 11       Men
# 12       NaN
# 13       NaN
# 14       NaN
# 15     Women
# 16     Women
# 17     Women
# 18       Men
# 19     Women
# 20       Men

# %%
coaches.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 394 entries, 0 to 393
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Name        394 non-null    object
#  1   NOC         394 non-null    object
#  2   Discipline  394 non-null    object
#  3   Event       249 non-null    object
# dtypes: object(4)
# memory usage: 12.4+ KB

# %%
# to avoid null replationship value
coaches['Event']=coaches['Event'].fillna('Unknown')

# %%
coaches.head()
# Out:
#               Name            NOC  Discipline    Event
# 0  ABDELMAGID Wael          Egypt    Football  Unknown
# 1        ABE Junya          Japan  Volleyball  Unknown
# 2    ABE Katsuhiko          Japan  Basketball  Unknown
# 3     ADAMA Cherif  Côte d'Ivoire    Football  Unknown
# 4       AGEBA Yuya          Japan  Volleyball  Unknown

# %%
coaches.to_csv (r'olympic_coaches.csv', index = False, header=True)

# %% [markdown]
# ### Medals Tally country wise

# %%
medal_country = pd.read_excel('Medals.xlsx', engine='openpyxl')
medal_country.head(100)
# Out:
#     Rank                    Team/NOC  Gold  Silver  Bronze  Total  \
# 0      1  People's Republic of China    32      22      16     70
# 1      2    United States of America    25      30      22     77
# 2      3                       Japan    21       7      12     40
# 3      4               Great Britain    15      18      15     48
# 4      5                   Australia    15       4      17     36
# ..   ...                         ...   ...     ...     ...    ...
# 80    79                     Finland     0       0       1      1
# 81    79                       Ghana     0       0       1      1
# 82    79                      Kuwait     0       0       1      1
# 83    79                    Malaysia     0       0       1      1
# 84    79        Syrian Arab Republic     0       0       1      1
#
#     Rank by Total
# 0               2
# 1               1
# 2               5
# 3               4
# 4               6
# ..            ...
# 80             71
# 81             71
# 82             71
# 83             71
# 84             71
#
# [85 rows x 7 columns]

# %%
medal_country.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 85 entries, 0 to 84
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Rank           85 non-null     int64
#  1   Team/NOC       85 non-null     object
#  2   Gold           85 non-null     int64
#  3   Silver         85 non-null     int64
#  4   Bronze         85 non-null     int64
#  5   Total          85 non-null     int64
#  6   Rank by Total  85 non-null     int64
# dtypes: int64(6), object(1)
# memory usage: 4.8+ KB

# %%
medal_country.to_csv (r'olympic_medal_country.csv', index = False, header=True)

# %% [markdown]
# ### Medals Player wise list

# %%
medal_player=pd.read_excel('olympic_medal_player.xlsx', engine="openpyxl")
medal_player.head()
# Out:
#                           NOC           Name Sport                  Event  \
# 0  People's Republic of China   ZOU Jingyuan   GAR    Men's Parallel Bars
# 1  People's Republic of China       LIU Yang   GAR            Men's Rings
# 2  People's Republic of China  GUAN Chenchen   GAR   Women's Balance Beam
# 3  People's Republic of China    LIU Shiying   ATH  Women's Javelin Throw
# 4  People's Republic of China    GONG Lijiao   ATH       Women's Shot Put
#
#   Medal
# 0     1
# 1     1
# 2     1
# 3     1
# 4     1

# %%
medal_player.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 915 entries, 0 to 914
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   NOC     915 non-null    object
#  1   Name    915 non-null    object
#  2   Sport   915 non-null    object
#  3   Event   915 non-null    object
#  4   Medal   915 non-null    object
# dtypes: object(5)
# memory usage: 35.9+ KB

# %%
#Replace 1 with gold keyword
medal_player['Medal']=medal_player['Medal'].replace([1],'gold')

# %%
#Replace 2 with gold keyword
medal_player['Medal']=medal_player['Medal'].replace([2],'silver')

# %%
#Replace 1 with gold keyword
medal_player['Medal']=medal_player['Medal'].replace([3],'bronze')

# %%
medal_player
# Out:
#                             NOC                  Name Sport  \
# 0    People's Republic of China          ZOU Jingyuan   GAR
# 1    People's Republic of China              LIU Yang   GAR
# 2    People's Republic of China         GUAN Chenchen   GAR
# 3    People's Republic of China           LIU Shiying   ATH
# 4    People's Republic of China           GONG Lijiao   ATH
# ..                          ...                   ...   ...
# 910                  Kyrgyzstan  ZHUMANAZAROVA Meerim   WRE
# 911                     Armenia         DAVTYAN Artur   GAR
# 912                     Armenia     BACHKOV Hovhannes   BOX
# 913                     Armenia     MARTIROSYAN Simon   WLF
# 914                     Armenia      ALEKSANYAN Artur   WRE
#
#                       Event   Medal
# 0       Men's Parallel Bars    gold
# 1               Men's Rings    gold
# 2      Women's Balance Beam    gold
# 3     Women's Javelin Throw    gold
# 4          Women's Shot Put    gold
# ..                      ...     ...
# 910  Women's Freestyle 68kg  bronze
# 911             Men's Vault  bronze
# 912   Men's Light (57-63kg)  bronze
# 913             Men's 109kg  silver
# 914  Men's Greco-Roman 97kg  silver
#
# [915 rows x 5 columns]

# %% [markdown]
# ### Sports code

# %%
sport_code=pd.read_excel('olympic_sport_code.xlsx', engine="openpyxl")
sport_code.head()
# Out:
#   Sport       Description
# 0   AQU    Aquatics Sport
# 1   ARC  Archery Aquatics
# 2   ATH         Athletics
# 3   BDM         Badminton
# 4   BK3    3x3 Basketball

# %%
#mergin player country wise with code
medal_player=pd.merge(medal_player, sport_code, on="Sport")

# %%
medal_player
# Out:
#                             NOC           Name Sport                 Event  \
# 0    People's Republic of China   ZOU Jingyuan   GAR   Men's Parallel Bars
# 1    People's Republic of China       LIU Yang   GAR           Men's Rings
# 2    People's Republic of China  GUAN Chenchen   GAR  Women's Balance Beam
# 3    People's Republic of China   XIAO Ruoteng   GAR      Men's All-Around
# 4    People's Republic of China        YOU Hao   GAR           Men's Rings
# ..                          ...            ...   ...                   ...
# 909                        Fiji           Fiji   RUG                 Women
# 910                   Argentina      Argentina   RUG                   Men
# 911                      Canada         Canada   FBL                 Women
# 912                      Sweden         Sweden   FBL                 Women
# 913                      Mexico         Mexico   FBL                   Men
#
#       Medal          Description
# 0      gold  Artistic Gymnastics
# 1      gold  Artistic Gymnastics
# 2      gold  Artistic Gymnastics
# 3    silver  Artistic Gymnastics
# 4    silver  Artistic Gymnastics
# ..      ...                  ...
# 909  bronze                Rugby
# 910  bronze                Rugby
# 911    gold             Football
# 912  silver             Football
# 913  bronze             Football
#
# [914 rows x 6 columns]

# %%
#download medal player along with sport code descriptions 
medal_player.to_csv (r'olympic_medal_player.csv', index = False, header=True)
